# %%
import tensorflow as tf

# %%
n1=tf.constant(2)

# %%
n2=tf.constant(10)

# %%
n3=n1+n2

# %%
with tf.Session() as sess:
  result= sess.run(n3)

# %%
result
# Out:
# 12

# %%
n3
# Out:
# <tf.Tensor 'add:0' shape=() dtype=int32>

# %%
tf.get_default_graph()

# %%
g1=tf.Graph()
g1

# %%
g1=tf.get_default_graph()
g1

# %%
g2=tf.Graph()
g2

# %%
with g2.as_default(): # default graph in the scope of with statement outside g1 is the default graph
  print(g2 is tf.get_default_graph())
# Out:
# True

# %%
print(g2 is tf.get_default_graph())
# Out:
# False
